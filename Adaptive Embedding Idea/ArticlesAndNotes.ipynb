# %% [markdown]
# SPA = https://steveryan.net/steganalysis-sample-pairs-analysis-explained.html

# %% [markdown]
# LSB Matching = https://daniellerch.me/image-stego-lsbm/

# %% [markdown]
# Matrix = https://pmc.ncbi.nlm.nih.gov/articles/PMC4766181/

# %% [markdown]
# Pixel Pair Matching = https://globaljournals.org/GJRE_Volume14/3-A-Secure-Steganographic.pdf

# %% [markdown]
# First 1000 of bossbase : Chi2 avg : 0.29645, Max Chi2 : 44.44219, Min Chi2 : 0.00000
# SPA avg  : 1.34720, Max SPA  : 1.92100, Min SPA  : 0.97376

# %% [markdown]
# To consider :
# - Min instead of max?
# - Should try find the actual embed rate and create a LSB random with that embed rate to get a better comparison

# %% [markdown]
# LSB Plane Autocorrection (To read) : https://sites.psu.edu/farshidfarhat/tag/relative-autocorrelation/
#
# http://dihana.cps.unizar.es/proceedings/ICASSP/2003/pdfs/03-00545.pdf TO READ

# %% [markdown]
# To read : https://scialert.net/fulltext/?doi=itj.2010.1725.1738

# %% [markdown]
# LSB matching detection (to read) : http://www0.cs.ucl.ac.uk/staff/I.Cox/Content/papers/2007/MMSP2007.pdf
